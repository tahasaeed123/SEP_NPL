# %% [markdown]
# # Make funtion to scrape data

# %% [markdown]
# ### Scrape table of content

# %%
import requests
from bs4 import BeautifulSoup

# URL of the page you want to scrape
url = 'https://plato.stanford.edu/contents.html'

# Send a GET request to the URL
response = requests.get(url)

# Parse the HTML content of the page
soup = BeautifulSoup(response.content, 'html.parser')

# Find all <a> tags. You might need to be more specific based on the page structure
article_links = soup.find_all('a')

articles = list()
for link in article_links:
    href = link.get('href')
    full_url = f'https://plato.stanford.edu/{href}'
    articles.append(full_url)  # Or do something else with the link

articles
# Out:
# ['https://plato.stanford.edu/index.html',
#  'https://plato.stanford.edu/index.html',
#  'https://plato.stanford.edu/#',
#  'https://plato.stanford.edu/contents.html',
#  'https://plato.stanford.edu/new.html',
#  'https://plato.stanford.edu/https://plato.stanford.edu/cgi-bin/encyclopedia/random',
#  'https://plato.stanford.edu/published.html',
#  'https://plato.stanford.edu/archives/',
#  'https://plato.stanford.edu/#',
#  'https://plato.stanford.edu/info.html',
#  'https://plato.stanford.edu/about.html',
#  'https://plato.stanford.edu/board.html',
#  'https://plato.stanford.edu/cite.html',
#  'https://plato.stanford.edu/special-characters.html',
#  'https://plato.stanford.edu/tools/',
#  'https://plato.stanford.edu/contact.html',
#  'https://plato.stanford.edu/#',
#  'https://plato.stanford.edu/support/',
#  'https://plato.stanford.edu/support/friends.html',
#  'https://plato.stanford.edu/support/donate.html',
#  'https://plato.stanford.edu/support/sepia.html',
#  'https://plato.stanford.edu/#a',
#  'https://plato.stanford.edu/#b',
#  'https://plato.stanford.edu/#c',
#  'https://plato.stanford.edu/#d',
#  'https://plato.stanford.edu/#e',
#  'https://plato.stanford.edu/#f',
#  'https://plato.stanford.edu/#g',
#  'https://plato.stanford.edu/#h',
#  'https://plato.stanford.edu/#i',
#  'https://plato.stanford.edu/#j',
#  'https://plato.stanford.edu/#k',
#  'https://plato.stanford.edu/#l',
#  'https://plato.stanford.edu/#m',
#  'https://plato.stanford.edu/#n',
#  'https://plato.stanford.edu/#o',
#  'https://plato.stanford.edu/#p',
#  'https://plato.stanford.edu/#q',
#  'https://plato.stanford.edu/#r',
#  'https://plato.stanford.edu/#s',
#  'https://plato.stanford.edu/#t',
#  'https://plato.stanford.edu/#u',
#  'https://plato.stanford.edu/#v',
#  'https://plato.stanford.edu/#w',
#  'https://plato.stanford.edu/#x',
#  'https://plato.stanford.edu/#y',
#  'https://plato.stanford.edu/#z',
#  'https://plato.stanford.edu/None',
#  'https://plato.stanford.edu/entries/abduction/',
#  'https://plato.stanford.edu/entries/abelard/',
#  'https://plato.stanford.edu/entries/abhidharma/',
#  'https://plato.stanford.edu/entries/abilities/',
#  'https://plato.stanford.edu/entries/abner-burgos/',
#  'https://plato.stanford.edu/entries/abrabanel/',
#  'https://plato.stanford.edu/entries/abstract-objects/',
#  'https://plato.stanford.edu/entries/essential-accidental/',
#  'https://plato.stanford.edu/entries/action/',
#  'https://plato.stanford.edu/entries/shared-agency/',
#  'https://plato.stanford.edu/entries/logic-action/',
#  'https://plato.stanford.edu/entries/action-perception/',
#  'https://plato.stanford.edu/entries/qm-action-distance/',
#  'https://plato.stanford.edu/entries/possibilism-actualism/',
#  'https://plato.stanford.edu/entries/actualism-possibilism-ethics/',
#  'https://plato.stanford.edu/entries/adaptationism/',
#  'https://plato.stanford.edu/entries/addams-jane/',
#  'https://plato.stanford.edu/entries/adorno/',
#  'https://plato.stanford.edu/entries/advance-directives/',
#  'https://plato.stanford.edu/entries/giles/',
#  'https://plato.stanford.edu/entries/skepticism-ancient/',
#  'https://plato.stanford.edu/entries/aesthetic-concept/',
#  'https://plato.stanford.edu/entries/aesthetic-experience/',
#  'https://plato.stanford.edu/entries/aesthetics-19th-romantic/',
#  'https://plato.stanford.edu/entries/aesthetic-judgment/',
#  'https://plato.stanford.edu/entries/beardsley-aesthetics/',
#  'https://plato.stanford.edu/entries/aesthetics-18th-british/',
#  'https://plato.stanford.edu/entries/aesthetics-cogsci/',
#  'https://plato.stanford.edu/entries/collingwood-aesthetics/',
#  'https://plato.stanford.edu/entries/croce-aesthetics/',
#  'https://plato.stanford.edu/entries/ethics-cultural-heritage/',
#  'https://plato.stanford.edu/entries/art-definition/',
#  'https://plato.stanford.edu/entries/dewey-aesthetics/',
#  'https://plato.stanford.edu/entries/environmental-aesthetics/',
#  'https://plato.stanford.edu/entries/aesthetics-existentialist/',
#  'https://plato.stanford.edu/entries/feminism-aesthetics/',
#  'https://plato.stanford.edu/entries/aesthetics-18th-french/',
#  'https://plato.stanford.edu/entries/gadamer-aesthetics/',
#  'https://plato.stanford.edu/entries/aesthetics-18th-german/',
#  'https://plato.stanford.edu/entries/goodman-aesthetics/',
#  'https://plato.stanford.edu/entries/hegel-aesthetics/',
#  'https://plato.stanford.edu/entries/heidegger-aesthetics/',
#  'https://plato.stanford.edu/entries/hume-aesthetics/',
#  'https://plato.stanford.edu/entries/japanese-aesthetics/',
#  'https://plato.stanford.edu/entries/plato-aesthetics/',
#  'https://plato.stanford.edu/entries/schopenhauer-aesthetics/',
#  'https://plato.stanford.edu/entries/wittgenstein-aesthetics/',
#  'https://plato.stanford.edu/entries/aesthetics-of-everyday/',
#  'https://plato.stanford.edu/entries/aesthetic-concept/',
#  'https://plato.stanford.edu/entries/affirmative-action/',
#  'https://plato.stanford.edu/entries/africana/',
#  'https://plato.stanford.edu/entries/africana-contemporary/',
#  'https://plato.stanford.edu/entries/african-ethics/',
#  'https://plato.stanford.edu/entries/african-sage/',
#  'https://plato.stanford.edu/entries/afterlife/',
#  'https://plato.stanford.edu/entries/agency/',
#  'https://plato.stanford.edu/entries/shared-agency/',
#  'https://plato.stanford.edu/entries/agent-modeling-philscience/',
#  'https://plato.stanford.edu/entries/reasons-agent/',
#  'https://plato.stanford.edu/entries/atheism-agnosticism/',
#  'https://plato.stanford.edu/entries/skepticism-ancient/',
#  'https://plato.stanford.edu/entries/agrippa-nettesheim/',
#  'https://plato.stanford.edu/entries/akan-person/',
#  'https://plato.stanford.edu/entries/weakness-will/',
#  'https://plato.stanford.edu/entries/al-baghdadi/',
#  'https://plato.stanford.edu/entries/al-farabi/',
#  'https://plato.stanford.edu/entries/al-farabi-metaphysics/',
#  'https://plato.stanford.edu/entries/al-farabi-logic/',
#  'https://plato.stanford.edu/entries/al-farabi-soc-rel/',
#  'https://plato.stanford.edu/entries/al-farabi-psych/',
#  'https://plato.stanford.edu/entries/al-ghazali/',
#  'https://plato.stanford.edu/entries/al-kindi/',
#  'https://plato.stanford.edu/entries/abu-bakr-al-razi/',
#  'https://plato.stanford.edu/entries/al-din-al-razi/',
#  'https://plato.stanford.edu/entries/albalag/',
#  'https://plato.stanford.edu/entries/albert-saxony/',
#  'https://plato.stanford.edu/entries/albert-great/',
#  'https://plato.stanford.edu/entries/albo-joseph/',
#  'https://plato.stanford.edu/entries/alcmaeon/',
#  'https://plato.stanford.edu/entries/alexander/',
#  'https://plato.stanford.edu/entries/alexander-aphrodisias/',
#  'https://plato.stanford.edu/entries/algebra/',
#  'https://plato.stanford.edu/entries/algebra-logic-tradition/',
#  'https://plato.stanford.edu/entries/alienation/',
#  'https://plato.stanford.edu/entries/althusser/',
#  'https://plato.stanford.edu/entries/altruism/',
#  'https://plato.stanford.edu/entries/altruism-biological/',
#  'https://plato.stanford.edu/entries/altruism-empirical/',
#  'https://plato.stanford.edu/entries/alyngton/',
#  'https://plato.stanford.edu/entries/ambiguity/',
#  'https://plato.stanford.edu/entries/ammonius/',
#  'https://plato.stanford.edu/entries/plotinus/',
#  'https://plato.stanford.edu/entries/analogy-medieval/',
#  'https://plato.stanford.edu/entries/reasoning-analogy/',
#  'https://plato.stanford.edu/entries/analysis/',
#  'https://plato.stanford.edu/entries/analytic-synthetic/',
#  'https://plato.stanford.edu/entries/anaphora/',
#  'https://plato.stanford.edu/entries/anarchism/',
#  'https://plato.stanford.edu/entries/anaxagoras/',
#  'https://plato.stanford.edu/entries/pyrrho/',
#  'https://plato.stanford.edu/entries/anderson-john/',
#  'https://plato.stanford.edu/entries/aristotle-commentators/',
#  'https://plato.stanford.edu/entries/cognition-animal/',
#  'https://plato.stanford.edu/entries/consciousness-animal/',
#  'https://plato.stanford.edu/entries/animalism/',
#  'https://plato.stanford.edu/entries/moral-animal/',
#  'https://plato.stanford.edu/entries/anomalous-monism/',
#  'https://plato.stanford.edu/entries/anscombe/',
#  'https://plato.stanford.edu/entries/anselm/',
#  'https://plato.stanford.edu/entries/moral-anti-realism/',
#  'https://plato.stanford.edu/entries/antiochus-ascalon/',
#  'https://plato.stanford.edu/entries/apriori/',
#  'https://plato.stanford.edu/entries/perception-episprob/',
#  'https://plato.stanford.edu/entries/skepticism/',
#  'https://plato.stanford.edu/entries/apriori/',
#  'https://plato.stanford.edu/entries/aquinas/',
#  'https://plato.stanford.edu/entries/aquinas-moral-political/',
#  'https://plato.stanford.edu/entries/arabic-islamic-metaphysics/',
#  'https://plato.stanford.edu/entries/arabic-islamic-natural/',
#  'https://plato.stanford.edu/entries/arabic-islamic-language/',
#  'https://plato.stanford.edu/entries/arabic-islamic-phil-math/',
#  'https://plato.stanford.edu/entries/arabic-islamic-religion/',
#  'https://plato.stanford.edu/entries/arabic-islamic-mind/',
#  'https://plato.stanford.edu/entries/arabic-islamic-greek/',
#  'https://plato.stanford.edu/entries/arabic-islamic-judaic/',
#  'https://plato.stanford.edu/entries/arabic-islamic-influence/',
#  'https://plato.stanford.edu/entries/ibn-kammuna/',
#  'https://plato.stanford.edu/entries/ikhwan-al-safa/',
#  'https://plato.stanford.edu/entries/arabic-islamic-mysticism/',
#  'https://plato.stanford.edu/entries/arcesilaus/',
#  'https://plato.stanford.edu/entries/architecture/',
#  'https://plato.stanford.edu/entries/archytas/',
#  'https://plato.stanford.edu/entries/arendt/',
#  'https://plato.stanford.edu/entries/ethics-ancient/',
#  'https://plato.stanford.edu/entries/argument/',
#  'https://plato.stanford.edu/entries/epistemic-utility/',
#  'https://plato.stanford.edu/entries/aristotle-commentators/',
#  'https://plato.stanford.edu/entries/aristotelianism-renaissance/',
#  'https://plato.stanford.edu/entries/aristotle/',
#  'https://plato.stanford.edu/entries/aristotle-commentators/',
#  'https://plato.stanford.edu/entries/alexander-aphrodisias/',
#  'https://plato.stanford.edu/entries/ammonius/',
#  'https://plato.stanford.edu/entries/david/',
#  'https://plato.stanford.edu/entries/elias/',
#  'https://plato.stanford.edu/entries/olympiodorus/',
#  'https://plato.stanford.edu/entries/philoponus/',
#  'https://plato.stanford.edu/entries/simplicius/',
#  'https://plato.stanford.edu/entries/aristotle-aesthetics/',
#  'https://plato.stanford.edu/entries/aristotle-biology/',
#  'https://plato.stanford.edu/entries/aristotle-categories/',
#  'https://plato.stanford.edu/entries/aristotle-ethics/',
#  'https://plato.stanford.edu/entries/aristotle-logic/',
#  'https://plato.stanford.edu/entries/aristotle-metaphysics/',
#  'https://plato.stanford.edu/entries/aristotle-politics/',
#  'https://plato.stanford.edu/entries/aristotle-psychology/',
#  'https://plato.stanford.edu/entries/aristotle-rhetoric/',
#  'https://plato.stanford.edu/entries/aristotle-causality/',
#  'https://plato.stanford.edu/entries/aristotle-mathematics/',
#  'https://plato.stanford.edu/entries/aristotle-natphil/',
#  'https://plato.stanford.edu/entries/aristotle-noncontradiction/',
#  'https://plato.stanford.edu/entries/arnauld/',
#  'https://plato.stanford.edu/entries/voltaire/',
#  'https://plato.stanford.edu/entries/arrows-theorem/',
#  'https://plato.stanford.edu/entries/erotic-art/',
#  'https://plato.stanford.edu/entries/conceptual-art/',
#  'https://plato.stanford.edu/entries/art-definition/',
#  'https://plato.stanford.edu/entries/artifact/',
#  'https://plato.stanford.edu/entries/artificial-intelligence/',
#  'https://plato.stanford.edu/entries/reasoning-automated/',
#  'https://plato.stanford.edu/entries/formal-belief/',
#  'https://plato.stanford.edu/entries/chinese-room/',
#  'https://plato.stanford.edu/entries/connectionism/',
#  'https://plato.stanford.edu/entries/reasoning-defeasible/',
#  'https://plato.stanford.edu/entries/ethics-ai/',
#  'https://plato.stanford.edu/entries/frame-problem/',
#  'https://plato.stanford.edu/entries/logic-ai/',
#  'https://plato.stanford.edu/entries/turing-test/',
#  'https://plato.stanford.edu/entries/tense-aspect/',
#  'https://plato.stanford.edu/entries/assertion/',
#  'https://plato.stanford.edu/entries/associationist-thought/',
#  'https://plato.stanford.edu/entries/astell/',
#  'https://plato.stanford.edu/entries/atheism-agnosticism/',
#  'https://plato.stanford.edu/entries/atomism-modern/',
#  'https://plato.stanford.edu/entries/atomism-ancient/',
#  'https://plato.stanford.edu/entries/atonement/',
#  'https://plato.stanford.edu/entries/attention/',
#  'https://plato.stanford.edu/entries/properties/',
#  'https://plato.stanford.edu/entries/perception-auditory/',
#  'https://plato.stanford.edu/entries/augustine/',
#  'https://plato.stanford.edu/entries/auriol/',
#  'https://plato.stanford.edu/entries/austin-john/',
#  'https://plato.stanford.edu/entries/austin-jl/',
#  'https://plato.stanford.edu/entries/authenticity/',
#  'https://plato.stanford.edu/entries/authority/',
#  'https://plato.stanford.edu/entries/legal-obligation/',
#  'https://plato.stanford.edu/entries/reasoning-automated/',
#  'https://plato.stanford.edu/entries/informed-consent/',
#  'https://plato.stanford.edu/entries/autonomy-moral/',
#  'https://plato.stanford.edu/entries/personal-autonomy/',
#  'https://plato.stanford.edu/entries/ibn-rushd/',
#  'https://plato.stanford.edu/entries/ibn-rushd-natural/',
#  'https://plato.stanford.edu/entries/ibn-gabirol/',
#  'https://plato.stanford.edu/entries/ibn-sina/',
#  'https://plato.stanford.edu/entries/ibn-sina-logic/',
#  'https://plato.stanford.edu/entries/ibn-sina-metaphysics/',
#  'https://plato.stanford.edu/entries/ibn-sina-natural/',
#  'https://plato.stanford.edu/entries/bodily-awareness/',
#  'https://plato.stanford.edu/entries/ayer/',
#  'https://plato.stanford.edu/None',
#  'https://plato.stanford.edu/#pagetopright',
#  'https://plato.stanford.edu/entries/francis-bacon/',
#  'https://plato.stanford.edu/entries/roger-bacon/',
#  'https://plato.stanford.edu/entries/scottish-19th/',
#  'https://plato.stanford.edu/entries/basing-epistemic/',
#  'https://plato.stanford.edu/entries/baudrillard/',
#  'https://plato.stanford.edu/entries/bauer/',
#  'https://plato.stanford.edu/entries/bayes-theorem/',
#  'https://plato.stanford.edu/entries/bayle/',
#  'https://plato.stanford.edu/entries/beardsley-aesthetics/',
#  'https://plato.stanford.edu/entries/scottish-18th/',
#  'https://plato.stanford.edu/entries/beauty/',
#  'https://plato.stanford.edu/entries/beauvoir/',
#  'https://plato.stanford.edu/entries/behaviorism/',
#  'https://plato.stanford.edu/entries/existence/',
#  'https://plato.stanford.edu/entries/time/',
#  'https://plato.stanford.edu/entries/spacetime-bebecome/',
#  'https://plato.stanford.edu/entries/belief/',
#  'https://plato.stanford.edu/entries/self-locating-beliefs/',
#  'https://plato.stanford.edu/entries/ethics-belief/',
#  'https://plato.stanford.edu/entries/formal-belief/',
#  'https://plato.stanford.edu/entries/belief-merging/',
#  'https://plato.stanford.edu/entries/bell-theorem/',
#  'https://plato.stanford.edu/entries/principle-beneficence/',
#  'https://plato.stanford.edu/entries/benjamin/',
#  'https://plato.stanford.edu/entries/bentham/',
#  'https://plato.stanford.edu/entries/bergson/',
#  'https://plato.stanford.edu/entries/berkeley/',
#  'https://plato.stanford.edu/entries/berlin/',
#  'https://plato.stanford.edu/entries/bessarion/',
#  'https://plato.stanford.edu/entries/implicit-bias/',
#  'https://plato.stanford.edu/entries/binarium/',
#  'https://plato.stanford.edu/entries/biodiversity/',
#  'https://plato.stanford.edu/entries/theories-biological-development/',
#  'https://plato.stanford.edu/entries/biology-individual/',
#  'https://plato.stanford.edu/entries/information-biological/',
#  'https://plato.stanford.edu/entries/conservation-biology/',
#  'https://plato.stanford.edu/entries/biology-developmental/',
#  'https://plato.stanford.edu/entries/biology-experiment/',
#  'https://plato.stanford.edu/entries/molecular-biology/',
#  'https://plato.stanford.edu/entries/biology-philosophy/',
#  'https://plato.stanford.edu/entries/reduction-biology/',
#  'https://plato.stanford.edu/entries/teleology-biology/',
#  'https://plato.stanford.edu/entries/feminist-philosophy-biology/',
#  'https://plato.stanford.edu/entries/biomedicine/',
#  'https://plato.stanford.edu/entries/scottish-18th/',
#  'https://plato.stanford.edu/entries/blame/',
#  'https://plato.stanford.edu/entries/bloch/',
#  'https://plato.stanford.edu/entries/bodily-awareness/',
#  'https://plato.stanford.edu/entries/bodin/',
#  'https://plato.stanford.edu/entries/substance/',
#  'https://plato.stanford.edu/entries/boethius/',
#  'https://plato.stanford.edu/entries/boethius-dacia/',
#  'https://plato.stanford.edu/entries/bohr-correspondence/',
#  'https://plato.stanford.edu/entries/bolzano/',
#  'https://plato.stanford.edu/entries/bolzano-logic/',
#  'https://plato.stanford.edu/entries/bonaventure/',
#  'https://plato.stanford.edu/entries/boole/',
#  'https://plato.stanford.edu/entries/boolalg-math/',
#  'https://plato.stanford.edu/entries/bosanquet/',
#  'https://plato.stanford.edu/entries/boundary/',
#  'https://plato.stanford.edu/entries/bounded-rationality/',
#  'https://plato.stanford.edu/entries/boyle/',
#  'https://plato.stanford.edu/entries/bradley/',
#  'https://plato.stanford.edu/entries/bradley-moral-political/',
#  'https://plato.stanford.edu/entries/bradley-regress/',
#  'https://plato.stanford.edu/entries/death-definition/',
#  'https://plato.stanford.edu/entries/skepticism-content-externalism/',
#  'https://plato.stanford.edu/entries/brentano/',
#  'https://plato.stanford.edu/entries/brentano-judgement/',
#  'https://plato.stanford.edu/entries/broad/',
#  'https://plato.stanford.edu/entries/brouwer/',
#  'https://plato.stanford.edu/entries/scottish-19th/',
#  'https://plato.stanford.edu/entries/bruno/',
#  'https://plato.stanford.edu/entries/buber/',
#  'https://plato.stanford.edu/entries/buddha/',
#  'https://plato.stanford.edu/entries/buddhism-chan/',
#  'https://plato.stanford.edu/entries/ethics-indian-buddhism/',
#  'https://plato.stanford.edu/entries/mind-indian-buddhism/',
#  'https://plato.stanford.edu/entries/buddhism-tiantai/',
#  'https://plato.stanford.edu/entries/japanese-zen/',
#  'https://plato.stanford.edu/entries/buddhism-huayan/',
#  'https://plato.stanford.edu/entries/substance/',
#  'https://plato.stanford.edu/entries/buridan/',
#  'https://plato.stanford.edu/entries/burke/',
#  'https://plato.stanford.edu/entries/burley/',
#  'https://plato.stanford.edu/entries/scottish-18th/',
#  'https://plato.stanford.edu/entries/butler-moral/',
#  'https://plato.stanford.edu/entries/byzantine-philosophy/',
#  'https://plato.stanford.edu/None',
#  'https://plato.stanford.edu/#pagetopright',
#  'https://plato.stanford.edu/entries/scottish-19th/',
#  'https://plato.stanford.edu/entries/callicles-thrasymachus/',
#  'https://plato.stanford.edu/entries/cambridge-platonists/',
#  'https://plato.stanford.edu/entries/campanella/',
#  'https://plato.stanford.edu/entries/scottish-18th/',
#  'https://plato.stanford.edu/entries/camus/',
#  'https://plato.stanford.edu/entries/cancer/',
#  'https://plato.stanford.edu/entries/capability-approach/',
#  'https://plato.stanford.edu/entries/cardano/',
#  'https://plato.stanford.edu/entries/scottish-18th/',
#  'https://plato.stanford.edu/entries/carnap/',
#  'https://plato.stanford.edu/entries/carneades/',
#  'https://plato.stanford.edu/entries/cassirer/',
#  'https://plato.stanford.edu/entries/reasoning-moral/',
#  'https://plato.stanford.edu/entries/categories/',
#  'https://plato.stanford.edu/entries/medieval-categories/',
#  'https://plato.stanford.edu/entries/category-mistakes/',
#  'https://plato.stanford.edu/entries/category-theory/',
#  'https://plato.stanford.edu/entries/determinism-causal/',
#  'https://plato.stanford.edu/entries/causal-models/',
#  'https://plato.stanford.edu/entries/causation-backwards/',
#  'https://plato.stanford.edu/entries/causation-counterfactual/',
#  'https://plato.stanford.edu/entries/arabic-islamic-causation/',
#  'https://plato.stanford.edu/entries/causation-physics/',
#  'https://plato.stanford.edu/entries/causation-law/',
#  'https://plato.stanford.edu/entries/causation-mani/',
#  'https://plato.stanford.edu/entries/causation-medieval/',
#  'https://plato.stanford.edu/entries/mental-causation/',
#  'https://plato.stanford.edu/entries/causation-metaphysics/',
#  'https://plato.stanford.edu/entries/causation-probabilistic/',
#  'https://plato.stanford.edu/entries/causation-regularity/',
#  'https://plato.stanford.edu/entries/qm-retrocausality/',
#  'https://plato.stanford.edu/entries/margaret-cavendish/',
#  'https://plato.stanford.edu/entries/cell-biology/',
#  'https://plato.stanford.edu/entries/cellular-automata/',
#  'https://plato.stanford.edu/entries/pornography-censorship/',
#  'https://plato.stanford.edu/entries/certainty/',
#  'https://plato.stanford.edu/entries/ceteris-paribus/',
#  'https://plato.stanford.edu/entries/chance-randomness/',
#  'https://plato.stanford.edu/entries/change/',
#  'https://plato.stanford.edu/entries/chinese-change/',
#  'https://plato.stanford.edu/entries/chaos/',
#  'https://plato.stanford.edu/entries/moral-character/',
#  'https://plato.stanford.edu/entries/moral-character-empirical/',
#  'https://plato.stanford.edu/entries/emilie-du-chatelet/',
#  'https://plato.stanford.edu/entries/walter-chatton/',
#  'https://plato.stanford.edu/entries/chemistry/',
#  'https://plato.stanford.edu/entries/childhood/',
#  'https://plato.stanford.edu/entries/children/',
#  'https://plato.stanford.edu/entries/philosophy-chile/',
#  'https://plato.stanford.edu/entries/chimeras/',
#  'https://plato.stanford.edu/entries/ethics-chinese/',
#  'https://plato.stanford.edu/entries/buddhism-chan/',
#  'https://plato.stanford.edu/entries/chinese-phil-medicine/',
#  'https://plato.stanford.edu/entries/comparphil-chiwes/',
#  'https://plato.stanford.edu/entries/confucius/',
#  'https://plato.stanford.edu/entries/daoism/',
#  'https://plato.stanford.edu/entries/emotions-chinese/',
#  'https://plato.stanford.edu/entries/chinese-epistemology/',
#  'https://plato.stanford.edu/entries/ethics-chinese/',
#  'https://plato.stanford.edu/entries/han-dynasty/',
#  'https://plato.stanford.edu/entries/buddhism-huayan/',
#  'https://plato.stanford.edu/entries/laozi/',
#  'https://plato.stanford.edu/entries/chinese-legalism/',
#  'https://plato.stanford.edu/entries/chinese-logic-language/',
#  'https://plato.stanford.edu/entries/mencius/',
#  'https://plato.stanford.edu/entries/chinese-metaphysics/',
#  'https://plato.stanford.edu/entries/chinese-mind/',
#  'https://plato.stanford.edu/entries/mohism/',
#  'https://plato.stanford.edu/entries/mohist-canons/',
#  'https://plato.stanford.edu/entries/neo-daoism/',
#  'https://plato.stanford.edu/entries/chinese-change/',
#  'https://plato.stanford.edu/entries/qing-philosophy/',
#  'https://plato.stanford.edu/entries/chinese-phil-science/',
#  'https://plato.stanford.edu/entries/chinese-social-political/',
#  'https://plato.stanford.edu/entries/song-ming-confucianism/',
#  'https://plato.stanford.edu/entries/buddhism-tiantai/',
#  'https://plato.stanford.edu/entries/chinese-translate-interpret/',
#  'https://plato.stanford.edu/entries/wang-yangming/',
#  'https://plato.stanford.edu/entries/xunzi/',
#  'https://plato.stanford.edu/entries/zhuangzi/',
#  'https://plato.stanford.edu/entries/zhu-xi/',
#  'https://plato.stanford.edu/entries/chinese-room/',
#  'https://plato.stanford.edu/entries/chisholm/',
#  'https://plato.stanford.edu/entries/axiom-choice/',
#  'https://plato.stanford.edu/entries/dynamic-choice/',
#  'https://plato.stanford.edu/entries/social-choice/',
#  'https://plato.stanford.edu/entries/christiantheology-philosophy/',
#  'https://plato.stanford.edu/entries/church/',
#  'https://plato.stanford.edu/entries/church-turing/',
#  'https://plato.stanford.edu/entries/church-turing/',
#  'https://plato.stanford.edu/entries/cicero/',
#  'https://plato.stanford.edu/entries/citizenship/',
#  'https://plato.stanford.edu/entries/civic-education/',
#  'https://plato.stanford.edu/entries/humanism-civic/',
#  'https://plato.stanford.edu/entries/civil-disobedience/',
#  'https://plato.stanford.edu/entries/civil-rights/',
#  'https://plato.stanford.edu/entries/clarke/',
#  'https://plato.stanford.edu/entries/doxography-ancient/',
#  'https://plato.stanford.edu/entries/justice-climate/',
#  'https://plato.stanford.edu/entries/climate-science/',
#  'https://plato.stanford.edu/entries/clinical-research/',
#  'https://plato.stanford.edu/entries/cloning/',
#  'https://plato.stanford.edu/entries/cockburn/',
#  'https://plato.stanford.edu/entries/coercion/',
#  'https://plato.stanford.edu/entries/cognition-animal/',
#  'https://plato.stanford.edu/entries/embodied-cognition/',
#  'https://plato.stanford.edu/entries/cognitive-disability/',
#  'https://plato.stanford.edu/entries/cognitive-science/',
#  'https://plato.stanford.edu/entries/moral-cognitivism/',
#  'https://plato.stanford.edu/entries/cohen/',
#  'https://plato.stanford.edu/entries/collingwood/',
#  'https://plato.stanford.edu/entries/collingwood-aesthetics/',
#  'https://plato.stanford.edu/entries/collins/',
#  'https://plato.stanford.edu/entries/colonialism/',
#  'https://plato.stanford.edu/entries/color/',
#  'https://plato.stanford.edu/entries/physics-Rpcc/',
#  'https://plato.stanford.edu/entries/common-good/',
#  'https://plato.stanford.edu/entries/common-knowledge/',
#  'https://plato.stanford.edu/entries/communitarianism/',
#  'https://plato.stanford.edu/entries/comparative-cognition/',
#  'https://plato.stanford.edu/entries/comparphil-chiwes/',
#  'https://plato.stanford.edu/entries/compatibilism/',
#  'https://plato.stanford.edu/entries/decision-capacity/',
#  'https://plato.stanford.edu/entries/computability/',
#  'https://plato.stanford.edu/entries/computational-complexity/',
#  'https://plato.stanford.edu/entries/problem-of-many/',
#  'https://plato.stanford.edu/entries/compositionality/',
#  'https://plato.stanford.edu/entries/computability/',
#  'https://plato.stanford.edu/entries/computation-physicalsystems/',
#  'https://plato.stanford.edu/entries/computational-complexity/',
#  'https://plato.stanford.edu/entries/computational-linguistics/',
#  'https://plato.stanford.edu/entries/computational-philosophy/',
#  'https://plato.stanford.edu/entries/computational-mind/',
#  'https://plato.stanford.edu/entries/computer-science/',
#  'https://plato.stanford.edu/entries/computing-history/',
#  'https://plato.stanford.edu/entries/computing-responsibility/',
#  'https://plato.stanford.edu/entries/comte/',
#  'https://plato.stanford.edu/entries/concepts/',
#  'https://plato.stanford.edu/entries/condemnation/',
#  'https://plato.stanford.edu/entries/condillac/',
#  'https://plato.stanford.edu/entries/conditionals/',
#  'https://plato.stanford.edu/entries/counterfactuals/',
#  'https://plato.stanford.edu/entries/logic-conditionals/',
#  'https://plato.stanford.edu/entries/histfem-condorcet/',
#  'https://plato.stanford.edu/entries/confirmation/',
#  'https://plato.stanford.edu/entries/confucian-gender/',
#  'https://plato.stanford.edu/entries/japanese-confucian/',
#  'https://plato.stanford.edu/entries/korean-confucianism/',
#  'https://plato.stanford.edu/entries/mencius/',
#  'https://plato.stanford.edu/entries/song-ming-confucianism/',
#  'https://plato.stanford.edu/entries/wang-yangming/',
#  'https://plato.stanford.edu/entries/xunzi/',
#  'https://plato.stanford.edu/entries/zhu-xi/',
#  'https://plato.stanford.edu/entries/confucius/',
#  'https://plato.stanford.edu/entries/connectionism/',
#  'https://plato.stanford.edu/entries/connectives-logic/',
#  'https://plato.stanford.edu/entries/conscience/',
#  'https://plato.stanford.edu/entries/conscience-medieval/',
#  'https://plato.stanford.edu/entries/consciousness/',
#  'https://plato.stanford.edu/entries/consciousness-animal/',
#  'https://plato.stanford.edu/entries/consciousness-higher/',
#  'https://plato.stanford.edu/entries/consciousness-intentionality/',
#  'https://plato.stanford.edu/entries/consciousness-neuroscience/',
#  'https://plato.stanford.edu/entries/consciousness-representational/',
#  'https://plato.stanford.edu/entries/consciousness-17th/',
#  'https://plato.stanford.edu/entries/consciousness-temporal/',
#  'https://plato.stanford.edu/entries/consciousness-unity/',
#  'https://plato.stanford.edu/entries/political-obligation/',
#  'https://plato.stanford.edu/entries/consequence-medieval/',
#  'https://plato.stanford.edu/entries/consequentialism/',
#  'https://plato.stanford.edu/entries/consequentialism-rule/',
#  'https://plato.stanford.edu/entries/consequentializing/',
#  'https://plato.stanford.edu/entries/conservation-biology/',
#  'https://plato.stanford.edu/entries/conservatism/',
#  'https://plato.stanford.edu/entries/constitutionalism/',
#  'https://plato.stanford.edu/entries/constructive-empiricism/',
#  'https://plato.stanford.edu/entries/constructivism-metaethics/',
#  'https://plato.stanford.edu/entries/contextualism-epistemology/',
#  'https://plato.stanford.edu/entries/continental-rationalism/',
#  'https://plato.stanford.edu/entries/continuity/',
#  'https://plato.stanford.edu/entries/continuum-hypothesis/',
#  'https://plato.stanford.edu/entries/contractarianism/',
#  'https://plato.stanford.edu/entries/contract-law/',
#  'https://plato.stanford.edu/entries/contractualism/',
#  'https://plato.stanford.edu/entries/contradiction/',
#  'https://plato.stanford.edu/entries/convention/',
#  'https://plato.stanford.edu/entries/moral-conventional/',
#  'https://plato.stanford.edu/entries/conway/',
#  'https://plato.stanford.edu/entries/anna-julia-cooper/',
#  'https://plato.stanford.edu/entries/copernicus/',
#  'https://plato.stanford.edu/entries/cordemoy/',
#  'https://plato.stanford.edu/entries/corruption/',
#  'https://plato.stanford.edu/entries/cosmological-argument/',
#  'https://plato.stanford.edu/entries/cosmology-30s/',
#  'https://plato.stanford.edu/entries/cosmology-theology/',
#  'https://plato.stanford.edu/entries/cosmology/',
#  'https://plato.stanford.edu/entries/cosmopolitanism/',
#  'https://plato.stanford.edu/entries/counterfactuals/',
#  'https://plato.stanford.edu/entries/possible-objects/',
#  'https://plato.stanford.edu/entries/crathorn/',
#  'https://plato.stanford.edu/entries/creation-conservation/',
#  'https://plato.stanford.edu/entries/creationism/',
#  'https://plato.stanford.edu/entries/creativity/',
#  'https://plato.stanford.edu/entries/crescas/',
#  'https://plato.stanford.edu/entries/criminal-law/',
#  'https://plato.stanford.edu/entries/critical-phil-race/',
#  'https://plato.stanford.edu/entries/critical-phil-race/',
#  'https://plato.stanford.edu/entries/critical-theory/',
#  'https://plato.stanford.edu/entries/critical-thinking/',
#  'https://plato.stanford.edu/entries/croce-aesthetics/',
#  'https://plato.stanford.edu/entries/alexander-crummell/',
#  'https://plato.stanford.edu/entries/cambridge-platonists/',
#  'https://plato.stanford.edu/entries/evolution-cultural/',
#  'https://plato.stanford.edu/entries/ethics-cultural-heritage/',
#  'https://plato.stanford.edu/entries/culture/',
#  'https://plato.stanford.edu/entries/culture-cogsci/',
#  'https://plato.stanford.edu/entries/cambridge-platonists/',
#  'https://plato.stanford.edu/entries/curry-paradox/',
#  'https://plato.stanford.edu/entries/cusanus/',
#  'https://plato.stanford.edu/None',
#  'https://plato.stanford.edu/#pagetopright',
#  'https://plato.stanford.edu/entries/peter-damian/',
#  'https://plato.stanford.edu/entries/dance/',
#  'https://plato.stanford.edu/entries/dante/',
#  'https://plato.stanford.edu/entries/daoism/',
#  'https://plato.stanford.edu/entries/laozi/',
#  'https://plato.stanford.edu/entries/neo-daoism/',
#  'https://plato.stanford.edu/entries/daoism-religion/',
#  'https://plato.stanford.edu/entries/zhuangzi/',
#  'https://plato.stanford.edu/entries/origin-descent/',
#  'https://plato.stanford.edu/entries/darwinism/',
#  'https://plato.stanford.edu/entries/heidegger/',
#  'https://plato.stanford.edu/entries/abraham-daud/',
#  'https://plato.stanford.edu/entries/david/',
#  'https://plato.stanford.edu/entries/davidson/',
#  'https://plato.stanford.edu/entries/death/',
#  'https://plato.stanford.edu/entries/death-definition/',
#  'https://plato.stanford.edu/entries/beauvoir/',
#  'https://plato.stanford.edu/entries/lying-definition/',
#  'https://plato.stanford.edu/entries/self-deception/',
#  'https://plato.stanford.edu/entries/decision-capacity/',
#  'https://plato.stanford.edu/entries/decision-theory/',
#  'https://plato.stanford.edu/entries/decision-causal/',
#  'https://plato.stanford.edu/entries/decision-theory-descriptive/',
#  'https://plato.stanford.edu/entries/rationality-normative-utility/',
#  'https://plato.stanford.edu/entries/rationality-normative-nonutility/',
#  'https://plato.stanford.edu/entries/dedekind-foundations/',
#  'https://plato.stanford.edu/entries/deductivism-mathematics/',
#  'https://plato.stanford.edu/entries/defaults-semantics-pragmatics/',
#  'https://plato.stanford.edu/entries/definitions/',
#  'https://plato.stanford.edu/entries/deleuze/',
#  'https://plato.stanford.edu/entries/delmedigo/',
#  'https://plato.stanford.edu/entries/delusion/',
#  'https://plato.stanford.edu/entries/pseudo-science/',
#  'https://plato.stanford.edu/entries/democracy/',
#  'https://plato.stanford.edu/entries/global-democracy/',
#  'https://plato.stanford.edu/entries/democritus/',
#  'https://plato.stanford.edu/entries/aristotle-logic/',
#  'https://plato.stanford.edu/entries/demonstration-medieval/',
#  'https://plato.stanford.edu/entries/indexicals/',
#  'https://plato.stanford.edu/entries/reference/',
#  'https://plato.stanford.edu/entries/ethics-deontological/',
#  'https://plato.stanford.edu/entries/dependence-ontological/',
#  'https://plato.stanford.edu/entries/depiction/',
#  'https://plato.stanford.edu/entries/derrida/',
#  'https://plato.stanford.edu/entries/descartes/',
#  'https://plato.stanford.edu/entries/descartes-epistemology/',
#  'https://plato.stanford.edu/entries/descartes-ethics/',
#  'https://plato.stanford.edu/entries/descartes-works/',
#  'https://plato.stanford.edu/entries/descartes-mathematics/',
#  'https://plato.stanford.edu/entries/descartes-method/',
#  'https://plato.stanford.edu/entries/descartes-modal/',
#  'https://plato.stanford.edu/entries/descartes-ontological/',
#  'https://plato.stanford.edu/entries/descartes-physics/',
#  'https://plato.stanford.edu/entries/pineal-gland/',
#  'https://plato.stanford.edu/entries/emotions-17th18th/',
#  'https://plato.stanford.edu/entries/descartes-ideas/',
#  'https://plato.stanford.edu/entries/descriptions/',
#  'https://plato.stanford.edu/entries/desert/',
#  'https://plato.stanford.edu/entries/desgabets/',
#  'https://plato.stanford.edu/entries/teleological-arguments/',
#  'https://plato.stanford.edu/entries/desire/',
#  'https://plato.stanford.edu/entries/determinate-determinables/',
#  'https://plato.stanford.edu/entries/freedom-ancient/',
#  'https://plato.stanford.edu/entries/determinism-causal/',
#  'https://plato.stanford.edu/entries/biology-developmental/',
#  'https://plato.stanford.edu/entries/evolution-development/',
#  'https://plato.stanford.edu/entries/theories-biological-development/',
#  'https://plato.stanford.edu/entries/dewey/',
#  'https://plato.stanford.edu/entries/dewey-aesthetics/',
#  'https://plato.stanford.edu/entries/dewey-moral/',
#  'https://plato.stanford.edu/entries/dewey-political/',
#  'https://plato.stanford.edu/entries/dharmakiirti/',
#  'https://plato.stanford.edu/entries/diagrams/',
#  'https://plato.stanford.edu/entries/epistemology-visual-thinking/',
#  'https://plato.stanford.edu/entries/dialectical-school/',
#  'https://plato.stanford.edu/entries/hegel-dialectics/',
#  'https://plato.stanford.edu/entries/dialetheism/',
#  'https://plato.stanford.edu/entries/diderot/',
#  'https://plato.stanford.edu/entries/dietrich-freiberg/',
#  'https://plato.stanford.edu/entries/digital-art/',
#  'https://plato.stanford.edu/entries/dignity/',
#  'https://plato.stanford.edu/entries/dilthey/',
#  'https://plato.stanford.edu/entries/diodorus-cronus/',
#  'https://plato.stanford.edu/entries/doxography-ancient/',
#  'https://plato.stanford.edu/entries/pseudo-dionysius-areopagite/',
#  'https://plato.stanford.edu/entries/dirty-hands/',
#  'https://plato.stanford.edu/entries/disability-critical/',
#  'https://plato.stanford.edu/entries/disability/',
#  'https://plato.stanford.edu/entries/feminism-disability/',
#  'https://plato.stanford.edu/entries/disability-health/',
#  'https://plato.stanford.edu/entries/disability-care-rationing/',
#  'https://plato.stanford.edu/entries/disability-justice/',
#  'https://plato.stanford.edu/entries/disagreement/',
#  'https://plato.stanford.edu/entries/disagreement-moral/',
#  'https://plato.stanford.edu/entries/discourse-representation-theory/',
#  'https://plato.stanford.edu/entries/discrimination/',
#  'https://plato.stanford.edu/entries/health-disease/',
#  'https://plato.stanford.edu/entries/disjunction/',
#  'https://plato.stanford.edu/entries/dispositions/',
#  'https://plato.stanford.edu/entries/sophists/',
#  'https://plato.stanford.edu/entries/justice-distributive/',
#  'https://plato.stanford.edu/entries/justice-moral-psych/',
#  'https://plato.stanford.edu/entries/international-justice/',
#  'https://plato.stanford.edu/entries/religious-pluralism/',
#  'https://plato.stanford.edu/entries/voluntarism-theological/',
#  'https://plato.stanford.edu/entries/free-will-foreknowledge/',
#  'https://plato.stanford.edu/entries/divine-freedom/',
#  'https://plato.stanford.edu/entries/divine-hiddenness/',
#  'https://plato.stanford.edu/entries/illumination/',
#  'https://plato.stanford.edu/entries/providence-divine/',
#  'https://plato.stanford.edu/entries/divine-revelation/',
#  'https://plato.stanford.edu/entries/divine-simplicity/',
#  'https://plato.stanford.edu/entries/doing-allowing/',
#  'https://plato.stanford.edu/entries/marriage/',
#  'https://plato.stanford.edu/entries/domination/',
#  'https://plato.stanford.edu/entries/gametes-donation-sale/',
#  'https://plato.stanford.edu/entries/organ-donation/',
#  'https://plato.stanford.edu/entries/double-consciousness/',
#  'https://plato.stanford.edu/entries/double-effect/',
#  'https://plato.stanford.edu/entries/frederick-douglass/',
#  'https://plato.stanford.edu/entries/doxography-ancient/',
#  'https://plato.stanford.edu/entries/dreams-dreaming/',
#  'https://plato.stanford.edu/entries/dualism/',
#  'https://plato.stanford.edu/entries/dubois/',
#  'https://plato.stanford.edu/entries/du-bos/',
#  'https://plato.stanford.edu/entries/duhem/',
#  'https://plato.stanford.edu/entries/scottish-18th/',
#  'https://plato.stanford.edu/entries/duns-scotus/',
#  'https://plato.stanford.edu/entries/dutch-book/',
#  'https://plato.stanford.edu/entries/dynamic-epistemic/',
#  'https://plato.stanford.edu/entries/dynamic-semantics/',
#  'https://plato.stanford.edu/None',
#  'https://plato.stanford.edu/#pagetopright',
#  'https://plato.stanford.edu/entries/early-modern-india/',
#  'https://plato.stanford.edu/entries/meister-eckhart/',
#  'https://plato.stanford.edu/entries/ecological-genetics/',
#  'https://plato.stanford.edu/entries/ecology/',
#  'https://plato.stanford.edu/entries/biodiversity/',
#  'https://plato.stanford.edu/entries/conservation-biology/',
#  'https://plato.stanford.edu/entries/economics-early-modern/',
#  'https://plato.stanford.edu/entries/economics/',
#  'https://plato.stanford.edu/entries/ramsey-economics/',
#  'https://plato.stanford.edu/entries/economic-justice/',
#  'https://plato.stanford.edu/entries/education-philosophy/',
#  'https://plato.stanford.edu/entries/edwards/',
#  'https://plato.stanford.edu/entries/egalitarianism/',
#  'https://plato.stanford.edu/entries/egoism/',
#  'https://plato.stanford.edu/entries/ehrenfels/',
#  'https://plato.stanford.edu/entries/spacetime-holearg/',
#  'https://plato.stanford.edu/entries/einstein-philscience/',
#  'https://plato.stanford.edu/entries/elias/',
#  'https://plato.stanford.edu/entries/elisabeth-bohemia/',
#  'https://plato.stanford.edu/entries/properties-emergent/',
#  'https://plato.stanford.edu/entries/emerson/',
#  'https://plato.stanford.edu/entries/emotion/',
#  'https://plato.stanford.edu/entries/emotions-17th18th/',
#  'https://plato.stanford.edu/entries/emotions-chinese/',
#  'https://plato.stanford.edu/entries/emotion-Christian-tradition/',
#  'https://plato.stanford.edu/entries/medieval-emotions/',
#  'https://plato.stanford.edu/entries/empathy/',
#  'https://plato.stanford.edu/entries/empedocles/',
#  'https://plato.stanford.edu/entries/altruism-empirical/',
#  'https://plato.stanford.edu/entries/moral-character-empirical/',
#  'https://plato.stanford.edu/entries/psychology-normative-cognition/',
#  'https://plato.stanford.edu/entries/rationalism-empiricism/',
#  'https://plato.stanford.edu/entries/empiricism-ancient-medieval/',
#  'https://plato.stanford.edu/entries/constructive-empiricism/',
#  'https://plato.stanford.edu/entries/logical-empiricism/',
#  'https://plato.stanford.edu/entries/enlightenment/',
#  'https://plato.stanford.edu/entries/logical-consequence/',
#  'https://plato.stanford.edu/entries/information-entropy/',
#  'https://plato.stanford.edu/entries/envy/',
#  'https://plato.stanford.edu/entries/epictetus/',
#  'https://plato.stanford.edu/entries/epicurus/',
#  'https://plato.stanford.edu/entries/epiphenomenalism/',
#  'https://plato.stanford.edu/entries/episteme-techne/',
#  'https://plato.stanford.edu/entries/basing-epistemic/',
#  'https://plato.stanford.edu/entries/closure-epistemic/',
#  'https://plato.stanford.edu/entries/epistemic-paradoxes/',
#  'https://plato.stanford.edu/entries/epistemic-self-doubt/',
#  'https://plato.stanford.edu/entries/epistemic-utility/',
#  'https://plato.stanford.edu/entries/epistemology/',
#  'https://plato.stanford.edu/entries/epistemology-bayesian/',
#  'https://plato.stanford.edu/entries/contextualism-epistemology/',
#  'https://plato.stanford.edu/entries/epistemology-evolutionary/',
#  'https://plato.stanford.edu/entries/feminism-epistemology/',
#  'https://plato.stanford.edu/entries/epistemology-india/',
#  'https://plato.stanford.edu/entries/epistemology-latin-america/',
#  'https://plato.stanford.edu/entries/moral-epistemology/',
#  'https://plato.stanford.edu/entries/moral-epistemology-a-priori/',
#  'https://plato.stanford.edu/entries/epistemology-naturalized/',
#  'https://plato.stanford.edu/entries/reliabilism/',
#  'https://plato.stanford.edu/entries/epistemology-social/',
#  'https://plato.stanford.edu/entries/feminist-social-epistemology/',
#  'https://plato.stanford.edu/entries/epistemology-virtue/',
#  'https://plato.stanford.edu/entries/formal-epistemology/',
#  'https://plato.stanford.edu/entries/epsilon-calculus/',
#  'https://plato.stanford.edu/entries/equality/',
#  'https://plato.stanford.edu/entries/equal-ed-opportunity/',
#  'https://plato.stanford.edu/entries/equal-opportunity/',
#  'https://plato.stanford.edu/entries/equivME/',
#  'https://plato.stanford.edu/entries/erasmus/',
#  'https://plato.stanford.edu/entries/ergodic-hierarchy/',
#  'https://plato.stanford.edu/entries/scottus-eriugena/',
#  'https://plato.stanford.edu/entries/real-essence/',
#  'https://plato.stanford.edu/entries/essential-accidental/',
#  'https://plato.stanford.edu/entries/essential-accidental/',
#  'https://plato.stanford.edu/entries/eternity/',
#  'https://plato.stanford.edu/entries/actualism-possibilism-ethics/',
#  'https://plato.stanford.edu/entries/ethics-ancient/',
#  'https://plato.stanford.edu/entries/ethics-belief/',
#  'https://plato.stanford.edu/entries/ethics-business/',
#  'https://plato.stanford.edu/entries/ethics-chinese/',
#  'https://plato.stanford.edu/entries/ethics-deontological/',
#  'https://plato.stanford.edu/entries/ethics-environmental/',
#  'https://plato.stanford.edu/entries/feminism-ethics/',
#  'https://plato.stanford.edu/entries/ethics-indian-buddhism/',
#  'https://plato.stanford.edu/entries/ethics-internet-research/',
#  'https://plato.stanford.edu/entries/natural-law-ethics/',
#  'https://plato.stanford.edu/entries/identity-ethics/',
#  'https://plato.stanford.edu/entries/ethics-search/',
#  'https://plato.stanford.edu/entries/ethics-social-networking/',
#  'https://plato.stanford.edu/entries/thick-ethical-concepts/',
#  'https://plato.stanford.edu/entries/consequentialism/',
#  'https://plato.stanford.edu/entries/ethics-virtue/',
#  'https://plato.stanford.edu/entries/african-ethics/',
#  'https://plato.stanford.edu/entries/ethics-it-phenomenology/',
#  'https://plato.stanford.edu/entries/advance-directives/',
#  'https://plato.stanford.edu/entries/chimeras/',
#  'https://plato.stanford.edu/entries/clinical-research/',
#  'https://plato.stanford.edu/entries/cloning/',
#  'https://plato.stanford.edu/entries/decision-capacity/',
#  'https://plato.stanford.edu/entries/disability/',
#  'https://plato.stanford.edu/entries/health-disease/',
#  'https://plato.stanford.edu/entries/gametes-donation-sale/',
#  'https://plato.stanford.edu/entries/organ-donation/',
#  'https://plato.stanford.edu/entries/enhancement/',
#  'https://plato.stanford.edu/entries/informed-consent/',
#  'https://plato.stanford.edu/entries/justice-inequality-health/',
#  'https://plato.stanford.edu/entries/justice-healthcareaccess/',
#  'https://plato.stanford.edu/entries/ethics-pregnancy/',
#  'https://plato.stanford.edu/entries/privacy-medicine/',
#  'https://plato.stanford.edu/entries/publichealth-ethics/',
#  'https://plato.stanford.edu/entries/organs-sale/',
#  'https://plato.stanford.edu/entries/stem-cells/',
#  'https://plato.stanford.edu/entries/theory-bioethics/',
#  'https://plato.stanford.edu/entries/ethics-ancient/',
#  'https://plato.stanford.edu/entries/eugenics/',
#  'https://plato.stanford.edu/entries/euthanasia-voluntary/',
#  'https://plato.stanford.edu/entries/events/',
#  'https://plato.stanford.edu/entries/evidence/',
#  'https://plato.stanford.edu/entries/evidence-legal/',
#  'https://plato.stanford.edu/entries/confirmation/',
#  'https://plato.stanford.edu/entries/higher-order-evidence/',
#  'https://plato.stanford.edu/entries/concept-evil/',
#  'https://plato.stanford.edu/entries/evil-kinds-origins/',
#  'https://plato.stanford.edu/entries/evil/',
#  'https://plato.stanford.edu/entries/evolution/',
#  'https://plato.stanford.edu/entries/evolution-before-darwin/',
#  'https://plato.stanford.edu/entries/evolution-cultural/',
#  'https://plato.stanford.edu/entries/origin-descent/',
#  'https://plato.stanford.edu/entries/morality-biology/',
#  'https://plato.stanford.edu/entries/game-evolutionary/',
#  'https://plato.stanford.edu/entries/evolutionary-psychology/',
#  'https://plato.stanford.edu/entries/existence/',
#  'https://plato.stanford.edu/entries/existentialism/',
#  'https://plato.stanford.edu/entries/aesthetics-existentialist/',
#  'https://plato.stanford.edu/entries/aesthetic-experience/',
#  'https://plato.stanford.edu/entries/experimental-moral/',
#  'https://plato.stanford.edu/entries/experimental-philosophy/',
#  'https://plato.stanford.edu/entries/biology-experiment/',
#  'https://plato.stanford.edu/entries/physics-experiment/',
#  'https://plato.stanford.edu/entries/mathematics-explanation/',
#  'https://plato.stanford.edu/entries/metaphysical-explanation/',
#  'https://plato.stanford.edu/entries/scientific-explanation/',
#  'https://plato.stanford.edu/entries/exploitation/',
#  'https://plato.stanford.edu/entries/self-knowledge-externalism/',
#  'https://plato.stanford.edu/entries/content-externalism/',
#  'https://plato.stanford.edu/entries/intrinsic-extrinsic/',
#  'https://plato.stanford.edu/entries/ibn-ezra/',
#  'https://plato.stanford.edu/None',
#  'https://plato.stanford.edu/#pagetopright',
#  'https://plato.stanford.edu/entries/facts/',
#  'https://plato.stanford.edu/entries/faith/',
#  'https://plato.stanford.edu/entries/falaquera/',
#  'https://plato.stanford.edu/entries/fallacies/',
#  'https://plato.stanford.edu/entries/frantz-fanon/',
#  'https://plato.stanford.edu/entries/fatalism/',
#  'https://plato.stanford.edu/entries/fechner/',
#  'https://plato.stanford.edu/entries/federalism/',
#  'https://plato.stanford.edu/entries/feigl/',
#  'https://plato.stanford.edu/entries/margaret-fell/',
#  'https://plato.stanford.edu/entries/feminist-philosophy/',
#  'https://plato.stanford.edu/entries/femapproach-analytic/',
#  'https://plato.stanford.edu/entries/femapproach-continental/',
#  'https://plato.stanford.edu/entries/femapproach-analy-cont/',
#  'https://plato.stanford.edu/entries/femapproach-prag-cont/',
#  'https://plato.stanford.edu/entries/feminism-latin-america/',
#  'https://plato.stanford.edu/entries/femapproach-pragmatism/',
#  'https://plato.stanford.edu/entries/feminism-psychoanalysis/',
#  'https://plato.stanford.edu/entries/feminism-aesthetics/',
#  'https://plato.stanford.edu/entries/feminist-bioethics/',
#  'https://plato.stanford.edu/entries/feminism-environmental/',
#  'https://plato.stanford.edu/entries/feminism-epistemology/',
#  'https://plato.stanford.edu/entries/feminism-ethics/',
#  'https://plato.stanford.edu/entries/feminism-femhist/',
#  'https://plato.stanford.edu/entries/feminism-liberal/',
#  'https://plato.stanford.edu/entries/feminism-metaphysics/',
#  'https://plato.stanford.edu/entries/feminism-moralpsych/',
#  'https://plato.stanford.edu/entries/feminist-philosophy-biology/',
#  'https://plato.stanford.edu/entries/feminism-language/',
#  'https://plato.stanford.edu/entries/feminism-law/',
#  'https://plato.stanford.edu/entries/feminist-religion/',
#  'https://plato.stanford.edu/entries/feminism-political/',
#  'https://plato.stanford.edu/entries/feminist-social-epistemology/',
#  'https://plato.stanford.edu/entries/feminism-argumentation/',
#  'https://plato.stanford.edu/entries/feminism-autonomy/',
#  'https://plato.stanford.edu/entries/feminism-class/',
#  'https://plato.stanford.edu/entries/feminism-disability/',
#  'https://plato.stanford.edu/entries/feminism-globalization/',
#  'https://plato.stanford.edu/entries/feminism-objectification/',
#  'https://plato.stanford.edu/entries/feminist-power/',
#  'https://plato.stanford.edu/entries/feminism-rape/',
#  'https://plato.stanford.edu/entries/feminism-family/',
#  'https://plato.stanford.edu/entries/feminist-science/',
#  'https://plato.stanford.edu/entries/feminism-gender/',
#  'https://plato.stanford.edu/entries/feminist-sex-markets/',
#  'https://plato.stanford.edu/entries/feminist-body/',
#  'https://plato.stanford.edu/entries/feminism-self/',
#  'https://plato.stanford.edu/entries/feminism-trans/',
#  'https://plato.stanford.edu/entries/scottish-18th/',
#  'https://plato.stanford.edu/entries/scottish-19th/',
#  'https://plato.stanford.edu/entries/ludwig-feuerbach/',
#  'https://plato.stanford.edu/entries/feyerabend/',
#  'https://plato.stanford.edu/entries/johann-fichte/',
#  'https://plato.stanford.edu/entries/ficino/',
#  'https://plato.stanford.edu/entries/fiction/',
#  'https://plato.stanford.edu/entries/fictional-entities/',
#  'https://plato.stanford.edu/entries/fictionalism/',
#  'https://plato.stanford.edu/entries/fictionalism-mathematics/',
#  'https://plato.stanford.edu/entries/fictionalism-modal/',
#  'https://plato.stanford.edu/entries/fideism/',
#  'https://plato.stanford.edu/entries/film/',
#  'https://plato.stanford.edu/entries/money-finance/',
#  'https://plato.stanford.edu/entries/findlay/',
#  'https://plato.stanford.edu/entries/fine-tuning/',
#  'https://plato.stanford.edu/entries/fitch-paradox/',
#  'https://plato.stanford.edu/entries/fitness/',
#  'https://plato.stanford.edu/entries/fitting-attitude-theories/',
#  'https://plato.stanford.edu/entries/fitzralph/',
#  'https://plato.stanford.edu/entries/fleck/',
#  'https://plato.stanford.edu/entries/folkpsych-simulation/',
#  'https://plato.stanford.edu/entries/folkpsych-theory/',
#  'https://plato.stanford.edu/entries/philippa-foot/',
#  'https://plato.stanford.edu/entries/free-will-foreknowledge/',
#  'https://plato.stanford.edu/entries/forgiveness/',
#  'https://plato.stanford.edu/entries/formal-epistemology/',
#  'https://plato.stanford.edu/entries/formalism-mathematics/',
#  'https://plato.stanford.edu/entries/formal-belief/',
#  'https://plato.stanford.edu/entries/plato-metaphysics/',
#  'https://plato.stanford.edu/entries/form-matter/',
#  'https://plato.stanford.edu/entries/foucault/',
#  'https://plato.stanford.edu/entries/temporal-parts/',
#  'https://plato.stanford.edu/entries/frame-problem/',
#  'https://plato.stanford.edu/entries/francis-marchia/',
#  'https://plato.stanford.edu/entries/critical-theory/',
#  'https://plato.stanford.edu/entries/freedom-ancient/',
#  'https://plato.stanford.edu/entries/freedom-association/',
#  'https://plato.stanford.edu/entries/divine-freedom/',
#  'https://plato.stanford.edu/entries/liberty-positive-negative/',
#  'https://plato.stanford.edu/entries/freedom-speech/',
#  'https://plato.stanford.edu/entries/free-rider/',
#  'https://plato.stanford.edu/entries/freewill/',
#  'https://plato.stanford.edu/entries/incompatibilism-theories/',
#  'https://plato.stanford.edu/entries/free-will-foreknowledge/',
#  'https://plato.stanford.edu/entries/frege/',
#  'https://plato.stanford.edu/entries/frege-hilbert/',
#  'https://plato.stanford.edu/entries/frege-logic/',
#  'https://plato.stanford.edu/entries/frege-theorem/',
#  'https://plato.stanford.edu/entries/friendship/',
#  'https://plato.stanford.edu/entries/fuller-margaret/',
#  'https://plato.stanford.edu/entries/teleology-biology/',
#  'https://plato.stanford.edu/entries/propositional-function/',
#  'https://plato.stanford.edu/entries/recursive-functions/',
#  'https://plato.stanford.edu/entries/functionalism/',
#  'https://plato.stanford.edu/entries/fundamentality/',
#  'https://plato.stanford.edu/entries/future-contingents/',
#  'https://plato.stanford.edu/entries/medieval-futcont/',
#  'https://plato.stanford.edu/None',
#  'https://plato.stanford.edu/#pagetopright',
#  'https://plato.stanford.edu/entries/gadamer/',
#  'https://plato.stanford.edu/entries/gadamer-aesthetics/',
#  'https://plato.stanford.edu/entries/galen/',
#  'https://plato.stanford.edu/entries/galileo/',
#  'https://plato.stanford.edu/entries/games-abstraction/',
#  'https://plato.stanford.edu/entries/logic-games/',
#  'https://plato.stanford.edu/entries/logics-for-games/',
#  'https://plato.stanford.edu/entries/game-theory/',
#  'https://plato.stanford.edu/entries/epistemic-game/',
#  'https://plato.stanford.edu/entries/game-ethics/',
#  'https://plato.stanford.edu/entries/game-evolutionary/',
#  'https://plato.stanford.edu/entries/gangesa/',
#  'https://plato.stanford.edu/entries/gassendi/',
#  'https://plato.stanford.edu/entries/gelukpa/',
#  'https://plato.stanford.edu/entries/gene/',
#  'https://plato.stanford.edu/entries/generalized-quantifiers/',
#  'https://plato.stanford.edu/entries/genrel-early/',
#  'https://plato.stanford.edu/entries/generics/',
#  'https://plato.stanford.edu/entries/genetic-drift/',
#  'https://plato.stanford.edu/entries/genetics/',
#  'https://plato.stanford.edu/entries/ecological-genetics/',
#  'https://plato.stanford.edu/entries/genotype-phenotype/',
#  'https://plato.stanford.edu/entries/molecular-genetics/',
#  'https://plato.stanford.edu/entries/population-genetics/',
#  'https://plato.stanford.edu/entries/genomics/',
#  'https://plato.stanford.edu/entries/epistemology-geometry/',
#  'https://plato.stanford.edu/entries/geometry-finitism/',
#  'https://plato.stanford.edu/entries/geometry-19th/',
#  'https://plato.stanford.edu/entries/scottish-18th/',
#  'https://plato.stanford.edu/entries/18thGerman-preKant/',
#  'https://plato.stanford.edu/entries/gersonides/',
#  'https://plato.stanford.edu/entries/giles/',
#  'https://plato.stanford.edu/entries/justep-foundational/',
#  'https://plato.stanford.edu/entries/global-democracy/',
#  'https://plato.stanford.edu/entries/globalization/',
#  'https://plato.stanford.edu/entries/justice-global/',
#  'https://plato.stanford.edu/entries/god-necessary-being/',
#  'https://plato.stanford.edu/entries/god-ultimates/',
#  'https://plato.stanford.edu/entries/pragmatic-belief-god/',
#  'https://plato.stanford.edu/entries/cosmological-argument/',
#  ...]

# %% [markdown]
# ### Scrape article body

# %%
import requests
from bs4 import BeautifulSoup

def extract_body(url):
    """
    Extracts the body of an article from the given URL.

    Parameters:
    url (str): The URL of the article to scrape.

    Returns:
    str: The cleaned text of the article.
    """
    try:
        # Send a GET request to the URL
        response = requests.get(url)

        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract the main content of the article
        article_body = soup.find('div', {'id': 'main-text'})
        
        # Extract text and replace newline characters with a space
        article_text = ' '.join(article_body.stripped_strings) if article_body else 'Content not found'
        article_text = article_text.replace('\n',' ')
        
        return article_text

    except Exception as e:
        return f"An error occurred: {e}"

# Example usage:
url = 'https://plato.stanford.edu/entries/abduction/'
text = extract_body(url)
text
# Out:
# '1. Abduction: The General Idea You happen to know that Tim and Harry have recently had a terrible row that ended their friendship. Now someone tells you that she just saw Tim and Harry jogging together. The best explanation for this that you can think of is that they made up. You conclude that they are friends again. One morning you enter the kitchen to find a plate and cup on the table, with breadcrumbs and a pat of butter on it, and surrounded by a jar of jam, a pack of sugar, and an empty carton of milk. You conclude that one of your house-mates got up at night to make him- or herself a midnight snack and was too tired to clear the table. This, you think, best explains the scene you are facing. To be sure, it might be that someone burgled the house and took the time to have a bite while on the job, or a house-mate might have arranged the things on the table without having a midnight snack but just to make you believe that someone had a midnight snack. But these hypotheses strike you as providing much more contrived explanations of the data than the one you infer to. Walking along the beach, you see what looks like a picture of Winston Churchill in the sand. It could be that, as in the opening pages of Hilary Putnam’s book Reason, Truth, and History , (1981), what you see is actually the trace of an ant crawling on the beach. The much simpler, and therefore (you think) much better, explanation is that someone intentionally drew a picture of Churchill in the sand. That, in any case, is what you come away believing. In these examples, the conclusions do not follow logically from the premises. For instance, it does not follow logically that Tim and Harry are friends again from the premises that they had a terrible row which ended their friendship and that they have just been seen jogging together; it does not even follow, we may suppose, from all the information you have about Tim and Harry. Nor do you have any useful statistical data about friendships, terrible rows, and joggers that might warrant an inference from the information that you have about Tim and Harry to the conclusion that they are friends again, or even to the conclusion that, probably (or with a certain probability), they are friends again. What leads you to the conclusion, and what according to a considerable number of philosophers may also warrant this conclusion, is precisely the fact that Tim and Harry’s being friends again would, if true, best explain the fact that they have just been seen jogging together. (The proviso that a hypothesis be true if it is to explain anything is taken as read from here on.) Similar remarks apply to the other two examples. The type of inference exhibited here is called abduction or, somewhat more commonly nowadays, Inference to the Best Explanation . 1.1 Deduction, induction, abduction Abduction is normally thought of as being one of three major types of inference, the other two being deduction and induction. The distinction between deduction, on the one hand, and induction and abduction, on the other hand, corresponds to the distinction between necessary and non-necessary inferences. In deductive inferences, what is inferred is necessarily true if the premises from which it is inferred are true; that is, the truth of the premises guarantees the truth of the conclusion. A familiar type of example is inferences instantiating the schema All A s are B s. a is an A . Hence, a is a B . But not all inferences are of this variety. Consider, for instance, the inference of “John is rich” from “John lives in Chelsea” and “Most people living in Chelsea are rich.” Here, the truth of the first sentence is not guaranteed (but only made likely) by the joint truth of the second and third sentences. Differently put, it is not necessarily the case that if the premises are true, then so is the conclusion: it is logically compatible with the truth of the premises that John is a member of the minority of non-rich inhabitants of Chelsea. The case ...

# %% [markdown]
# ### scrape biliography list

# %%
import requests
from bs4 import BeautifulSoup

def extract_bibliography(url):
    """
    Extracts the bibliography from the given URL.

    Parameters:
    url (str): The URL of the article to scrape.

    Returns:
    list: A list of bibliography entries.
    """
    try:
        # Send a GET request to the URL
        response = requests.get(url)

        # Parse the HTML content of the page
        soup = BeautifulSoup(response.content, 'html.parser')

        # Extract the bibliography
        bibliography = soup.find('div', {'id': 'bibliography'})
        bibliography_entries = []
        if bibliography:
            # Extract text from each <li> tag within the bibliography section
            for li in bibliography.find_all('li'):
                bibliography_entries.append(' '.join(li.stripped_strings))

        return bibliography_entries

    except Exception as e:
        return f"An error occurred: {e}"

# Example usage
url = 'https://plato.stanford.edu/entries/abduction/'
bibliography_entries = bibliography_extract(url)
pd.DataFrame(bibliography_entries)
# Out:
#                                                      0
# 0    Achinstein, P., 2001. The Book of Evidence , O...
# 1    Adler, J., 1994. “Testimony, Trust, Knowing,” ...
# 2    Bach, K. and Harnish, R., 1979. Linguistic Com...
# 3    Bird, A., 1998. Philosophy of Science , London...
# 4    Bigelow, J., 2010. “Quine, Mereology, and Infe...
# ..                                                 ...
# 106  –––, 2005. “The Refutation of\nSkepticism,” in...
# 107  Weintraub, R., 2013. “Induction and Inference ...
# 108  Weisberg, J., 2009. “Locating IBE in the Bayes...
# 109  Williams, J. and Lombrozo, T., 2010. “The Role...
# 110  Williamson, T., 2017. “Semantic Paradoxes and ...
#
# [111 rows x 1 columns]

# %%
cite_len = []
for i in range(len(bibliography_entries)):
    cite_len.append(len(bibliography_entries[i]))

# %%
bib = pd.DataFrame(bibliography_entries)
bib.rename(columns = {0:'citation'}, inplace=True)
bib['char_len']= cite_len
print(bib.iloc[0:10])
# Out:
#                                             citation  char_len
# 0  Achinstein, P., 2001. The Book of Evidence , O...        77
# 1  Adler, J., 1994. “Testimony, Trust, Knowing,” ...        82
# 2  Bach, K. and Harnish, R., 1979. Linguistic Com...        99
# 3  Bird, A., 1998. Philosophy of Science , London...        58
# 4  Bigelow, J., 2010. “Quine, Mereology, and Infe...       112
# 5  Bovens, L. and Hartmann, S., 2003. “Solving th...        90
# 6  Boyd, R., 1981. “Scientific Realism and Natura...       189
# 7  –––, 1984. “The Current Status of\nScientific ...       151
# 8  –––, 1985. “Lex Orandi est Lex\nCredendi,” in ...       151
# 9  Brem, S. and Rips, L. J., 2000. “Explanation a...       113

# %% [markdown]
# # Use Funtions

# %%
body_list = list()
bibliography_list = list()
topic_list = list()
url_list = list()

for url in set(articles[48:]):
    body = extract_body(url)
    body_list.append(body)
    
    biblio = extract_bibliography(url)
    bibliography_list.append(biblio)
    
    extract_topic = url.rsplit('/')[-2]
    topic_list.append(extract_topic)
    
    url_list.append(url)

# %%
# Make the data frame 
df = pd.DataFrame({
    'url': url_list,
    'topic': topic_list,
    'body': body_list,
    'bibliography': bibliography_list
                  })

# %%
from concurrent.futures import ThreadPoolExecutor

def scrape_url(url):
    body = extract_body(url)
    bibliography = extract_bibliography(url)
    topic = url.rsplit('/')[-2]
    return {'url': url, 'topic': topic, 'body': body, 'bibliography': bibliography}

# List of URLs to scrape
urls = set(articles[48:])

# Using ThreadPoolExecutor to fetch data concurrently
with ThreadPoolExecutor(max_workers=10) as executor:
    results = list(executor.map(scrape_url, urls))

# Convert list of dictionaries to DataFrame
df = pd.DataFrame(results)

# %%
# Convert list of dictionaries to DataFrame
df = pd.DataFrame(results)
# Out:
#                                                     url  \
# 0      https://plato.stanford.edu/entries/kant-leibniz/
# 1             https://plato.stanford.edu/entries/james/
# 2        https://plato.stanford.edu/entries/heytesbury/
# 3     https://plato.stanford.edu/entries/latin-ameri...
# 4        https://plato.stanford.edu/entries/madhyamaka/
# ...                                                 ...
# 1814  https://plato.stanford.edu/entries/critical-th...
# 1815  https://plato.stanford.edu/entries/sylvan-rout...
# 1816   https://plato.stanford.edu/entries/hermeneutics/
# 1817              https://plato.stanford.edu/board.html
# 1818  https://plato.stanford.edu/entries/kant-religion/
#
#                         topic  \
# 0                kant-leibniz
# 1                       james
# 2                  heytesbury
# 3     latin-american-analytic
# 4                  madhyamaka
# ...                       ...
# 1814        critical-thinking
# 1815           sylvan-routley
# 1816             hermeneutics
# 1817       plato.stanford.edu
# 1818            kant-religion
#
#                                                    body  \
# 0     1. Introduction Leibniz and his follower Chris...
# 1     1. Chronology of James’s Life 1842. Born in Ne...
# 2     1. Life and Works William Heytesbury was most ...
# 3     1. Geographical and Theoretical Boundaries Thi...
# 4     1. Issues in the Madhyamaka school There a num...
# ...                                                 ...
# 1814  1. History Use of the term ‘critical thinking’...
# 1815  1. Life Sylvan was born in 1935 in Levin, New ...
# 1816  1. Interpretive Experience The topic of this a...
# 1817                                  Content not found
# 1818  1. Overview The impression through the twentie...
#
#                                            bibliography
# 0     [References to Leibniz’s texts are to C.I. Ger...
# 1     [The Works of William James , Cambridge, MA an...
# 2     [[CO] Casus\nobligationis, [DML] De motu\nloca...
# 3     [Análisis Filosófico (vol. 13, no. 1, 1993).\n...
# 4     [Ames, William L., 1993. Bhāvaviveka’s Prajñāp...
# ...                                                 ...
# 1814  [Abrami, Philip C., Robert M. Bernard, Eugene ...
# 1815  [Brady, R. and Routley, R., 1973, “Don't Care ...
# 1816  [Alcoff, Linda Martín, 2006, Visible Identitie...
# 1817                                                 []
# 1818  [[AK] Königlichen Preußischen (later Deutschen...
#
# [1819 rows x 4 columns]

# %%
exclude_urls= df[df['bibliography'].apply(lambda x: x==[])]['url']
# Out:
# 96        https://plato.stanford.edu/support/friends.html
# 210        https://plato.stanford.edu/support/donate.html
# 224                https://plato.stanford.edu/info.html#c
# 513                  https://plato.stanford.edu/info.html
# 527                     https://plato.stanford.edu/tools/
# 573     https://plato.stanford.edu/https://mally.stanf...
# 607             https://plato.stanford.edu/published.html
# 799     https://plato.stanford.edu/entries/memory-epis...
# 801               https://plato.stanford.edu/mirrors.html
# 869         https://plato.stanford.edu/support/sepia.html
# 906                  https://plato.stanford.edu/archives/
# 941              https://plato.stanford.edu/contents.html
# 1032                https://plato.stanford.edu/about.html
# 1111    https://plato.stanford.edu/https://plato.stanf...
# 1129     https://plato.stanford.edu/entries/rights-group/
# 1149    https://plato.stanford.edu/projected-contents....
# 1153    https://plato.stanford.edu/special-characters....
# 1286                      https://plato.stanford.edu/None
# 1453                 https://plato.stanford.edu/cite.html
# 1562             https://plato.stanford.edu/#pagetopright
# 1616              https://plato.stanford.edu/contact.html
# 1648                  https://plato.stanford.edu/new.html
# 1694                         https://plato.stanford.edu/#
# 1760    https://plato.stanford.edu/https://plato.stanf...
# 1795                  https://plato.stanford.edu/support/
# 1817                https://plato.stanford.edu/board.html
# Name: url, dtype: object
